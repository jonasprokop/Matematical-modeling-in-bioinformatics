# %%
import sys 
from cellular_automata_meca import Meca_Cellular_Automata

# %%
# Initialise cellular automaton with 500x500 grid
meca = Meca_Cellular_Automata(500, 500)

# Simulate the whole space of rules
meca._simulate_all_rules()
# Out:
# I have solved grids for rules num 0 - 10
# I have solved grids for rules num 10 - 20
# I have solved grids for rules num 20 - 30
# I have solved grids for rules num 30 - 40
# I have solved grids for rules num 40 - 50
# I have solved grids for rules num 50 - 60
# I have solved grids for rules num 60 - 70
# I have solved grids for rules num 70 - 80
# I have solved grids for rules num 80 - 90
# I have solved grids for rules num 90 - 100
# I have solved grids for rules num 100 - 110
# I have solved grids for rules num 110 - 120
# I have solved grids for rules num 120 - 130
# I have solved grids for rules num 130 - 140
# I have solved grids for rules num 140 - 150
# I have solved grids for rules num 150 - 160
# I have solved grids for rules num 160 - 170
# I have solved grids for rules num 170 - 180
# I have solved grids for rules num 180 - 190
# I have solved grids for rules num 190 - 200
# I have solved grids for rules num 200 - 210
# I have solved grids for rules num 210 - 220
# ...

# %%
# Function to iterate through result space and visuale all of the rules
#meca.iterate_and_view_all_rules()

# %%
# Constatnt
meca.view_rule_number(0)

# %%
# Periodic
meca.view_rule_number(36)

# %%
# Chaotic
meca.view_rule_number(60)

# %%
# Complex
meca.view_rule_number(110)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
