# %%
from alzheimer_model import AlzheimerModel

# %%
model = AlzheimerModel(path_params="C:/sources/matematical_modeling_in_bioinformatics/Matematical-modeling-in-bioinformatics/term_project/params.yaml",
                       path_initial_state="C:/sources/matematical_modeling_in_bioinformatics/Matematical-modeling-in-bioinformatics/term_project/intial_state.yaml"
                       )

# %%
model.simulate()

# %%
results = model.show_results()

# %%
results
# Out:
# {'Neuron survival': {0: 10000.0,
#   1: 9997.5,
#   2: 9995.124375,
#   3: 9992.84842389061,
#   4: 9990.653638519478,
#   5: 9988.52615491951,
#   6: 9986.455591883543,
#   7: 9984.434180010578,
#   8: 9982.45610857691,
#   9: 9980.51703575442,
#   10: 9978.613721323058,
#   11: 9976.743751241873,
#   12: 9974.905331104843,
#   13: 9973.097131253515,
#   14: 9971.318170627137,
#   15: 9969.56772966207,
#   16: 9967.845284975303,
#   17: 9966.150460383871,
#   18: 9964.482990174614,
#   19: 9962.842691560452,
#   20: 9961.229444025663,
#   21: 9959.643173837214,
#   22: 9958.083842430142,
#   23: 9956.551437698074,
#   24: 9955.045967462318,
#   25: 9953.567454574686,
#   26: 9952.115933245424,
#   27: 9950.691446289886,
#   28: 9949.294043064148,
#   29: 9947.923777917287,
#   30: 9946.580709031081,
#   31: 9945.264897550263,
#   32: 9943.97640693065,
#   33: 9942.715302450655,
#   34: 9941.48165084534,
#   35: 9940.27552003234,
#   36: 9939.096978906702,
#   37: 9937.946097187387,
# ...

# %%
model.plot_scatter()
